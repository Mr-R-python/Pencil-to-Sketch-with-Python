# %% [markdown]
# # IMPORTING openCV LIBRARY

# %%
import cv2

# %% [markdown]
# # READ IMAGE

# %%
img=io.imread("C:\\Users\\rishabh\\Downloads\\coco.jpg")
img=cv2.resize(img,(500,650))
display(Image.fromarray(img))
# Out:
# <PIL.Image.Image image mode=RGB size=500x650 at 0x18F5A52A100>

# %% [markdown]
# # CONVERSION OF ORIGINAL IMAGE TO GRAY_SCALE

# %%
gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_img))
# Out:
# <PIL.Image.Image image mode=L size=500x650 at 0x18F5D575F10>

# %% [markdown]
# # CONVERSION OF GRAY_SCALE TO INVERTED_IMAGE

# %%
invert_img=cv2.bitwise_not(gray_img)
display(Image.fromarray(invert_img))
# Out:
# <PIL.Image.Image image mode=L size=500x650 at 0x18F5D57F430>

# %%
invert_img=cv2.bitwise_not(gray_img)
display(Image.fromarray(invert_img))
# Out:
# <PIL.Image.Image image mode=L size=500x650 at 0x18F5D57F2E0>

# %% [markdown]
# # BLURED IMAGE

# %%
blur=cv2.GaussianBlur(invert_img,(5,5),0,0)
display(Image.fromarray(blur))
# Out:
# <PIL.Image.Image image mode=L size=500x650 at 0x18F5D57FAC0>

# %% [markdown]
# # PENCIL_SKETCH

# %%
invert_blur=255-blur
pencil_sketch=cv2.divide(gray_img,invert_blur,scale=250.0)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=500x650 at 0x18F5D575BE0>

# %% [markdown]
# # COMPARISION OF PENCIL_SKETCH IMAGE WITH ORIGINAL IMAGE

# %%
display(Image.fromarray(img))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=500x650 at 0x18F5A527940>
# <PIL.Image.Image image mode=L size=500x650 at 0x18F5D575F10>
